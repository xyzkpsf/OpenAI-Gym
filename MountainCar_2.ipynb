# %% [markdown]
# <a href="https://colab.research.google.com/github/xyzkpsf/OpenAi-Gym/blob/master/MountainCar_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gym
import numpy as np
import pickle
from collections import defaultdict
import matplotlib.pyplot as plt
import time

# %%
#Hypter_parameters, 200K Training
# Discount, exploration_decay_rate, K, Learning rate, linear space interval,last 1000 Training average scores
# Best so far: 0.9, e_rate=4, K=1, (0.9, 0.015), 40, 200k-> -114

# %%
# provides a default value for the key that does not exists.
Q = defaultdict(lambda: [0, 0, 0])
VISITED = defaultdict(lambda: [0, 0, 0])

env = gym.make("MountainCar-v0")

# Map state space into a linear space
def linear_state(state):
    pos, v = state
    pos_low, v_low = env.observation_space.low
    pos_high, v_high = env.observation_space.high

    a = 40 * (pos - pos_low) / (pos_high - pos_low)
    b = 40 * (v - v_low) / (v_high - v_low)

    return int(a), int(b)

# hyperparameter
discount = 0.9
EPOCHS = 300000
score_list = []
exploration_decay_rate = 4
K = 1   # Exploration function constant

for epoch in range(EPOCHS):
    # take some linear function map lr from 0.9 to about 0.015
    lr = 0.9 - (epoch/EPOCHS)/1.13
    state = linear_state(env.reset())
    score = 0
    exploration_rate = 0.01 + (1-0.01)*np.exp(-exploration_decay_rate * epoch / EPOCHS)

   # if epoch > 200000:
   #   lr = 0.01
   #   exploration_rate = 0.01

    while True:
        action = np.argmax(Q[state])
        if np.random.random() <= exploration_rate:
            action = np.random.choice([0, 1, 2]) 

        next_s, reward, done, _ = env.step(action)
        if next_s[0] > 0.4:
            reward += 1
        next_s = linear_state(next_s)
        
        # Find the best action of S'
        optimal_next_a = -float('inf')
        for i in range(3):
            if Q[next_s][i] > optimal_next_a:
                optimal_next_a = i
        
        # Record the time that the (S', a') has been done
        VISITED[next_s][optimal_next_a] += 1
        
        Q[state][action] = (1 - lr) * Q[state][action] + lr * (reward + discount * (Q[next_s][optimal_next_a] + K / (VISITED[next_s][optimal_next_a] + 1)))
        score += reward
        state = next_s

        if done:
            score_list.append(score)
            if (epoch+1) % 10000 == 0:
                print('episode:', epoch, '; last 5000 score:', np.average((score_list[-5000:])), 'last 1000 score:', np.average((score_list[-1000:])), '; last 1000 max:', max((score_list[-1000:])))
            break
    ''''       
    if np.average((score_list[-1000:])) > -100:
        plt.plot(score_list)
        break
    '''        
env.close()

with open('MountainCar-v0-q-learning.pickle', 'wb') as f:
    pickle.dump(dict(Q), f)
    print('model saved')
# Out:
# episode: 9999 ; last 5000 score: -200.0 last 1000 score: -200.0 ; last 1000 max: -200.0
# episode: 19999 ; last 5000 score: -200.0 last 1000 score: -200.0 ; last 1000 max: -200.0
# episode: 29999 ; last 5000 score: -200.0 last 1000 score: -200.0 ; last 1000 max: -200.0
# episode: 39999 ; last 5000 score: -200.0 last 1000 score: -200.0 ; last 1000 max: -200.0
# episode: 49999 ; last 5000 score: -200.0 last 1000 score: -200.0 ; last 1000 max: -200.0
# episode: 59999 ; last 5000 score: -199.9982 last 1000 score: -199.991 ; last 1000 max: -191.0
# episode: 69999 ; last 5000 score: -199.8768 last 1000 score: -199.719 ; last 1000 max: -160.0
# episode: 79999 ; last 5000 score: -199.5282 last 1000 score: -199.435 ; last 1000 max: -160.0
# episode: 89999 ; last 5000 score: -198.3914 last 1000 score: -198.464 ; last 1000 max: -151.0
# episode: 99999 ; last 5000 score: -196.055 last 1000 score: -195.826 ; last 1000 max: -153.0
# episode: 109999 ; last 5000 score: -191.8442 last 1000 score: -188.706 ; last 1000 max: -146.0
# episode: 119999 ; last 5000 score: -185.6536 last 1000 score: -184.478 ; last 1000 max: -147.0
# episode: 129999 ; last 5000 score: -180.2038 last 1000 score: -179.67 ; last 1000 max: -135.0
# episode: 139999 ; last 5000 score: -174.3026 last 1000 score: -174.757 ; last 1000 max: -129.0
# episode: 149999 ; last 5000 score: -169.4806 last 1000 score: -167.676 ; last 1000 max: -129.0
# episode: 159999 ; last 5000 score: -168.3112 last 1000 score: -170.498 ; last 1000 max: -86.0
# episode: 169999 ; last 5000 score: -164.4828 last 1000 score: -165.014 ; last 1000 max: -110.0
# episode: 179999 ; last 5000 score: -163.1256 last 1000 score: -162.372 ; last 1000 max: -107.0
# episode: 189999 ; last 5000 score: -157.2052 last 1000 score: -157.491 ; last 1000 max: -92.0
# episode: 199999 ; last 5000 score: -154.4894 last 1000 score: -150.155 ; last 1000 max: -107.0
# episode: 209999 ; last 5000 score: -149.2866 last 1000 score: -142.54 ; last 1000 max: -104.0
# episode: 219999 ; last 5000 score: -152.774 last 1000 score: -148.03 ; last 1000 max: -89.0
# episode: 229999 ; last 5000 score: -148.3976 last 1000 score: -156.783 ; last 1000 max: -91.0
# episode: 239999 ; last 5000 score: -147.5436 last 1000 score: -144.801 ; last 1000 max: -83.0
# episode: 249999 ; last 5000 score: -140.79 last 1000 score: -149.611 ; last 1000 max: -83.0
# episode: 259999 ; last 5000 score: -142.6664 last 1000 score: -136.912 ; last 1000 max: -81.0
# episode: 269999 ; last 5000 score: -143.2424 last 1000 score: -146.978 ; last 1000 max: -81.0
# episode: 279999 ; last 5000 score: -138.0998 last 1000 score: -137.549 ; last 1000 max: -84.0
# episode: 289999 ; last 5000 score: -135.3842 last 1000 score: -136.295 ; last 1000 max: -81.0
# episode: 299999 ; last 5000 score: -125.0272 last 1000 score: -124.033 ; last 1000 max: -82.0
# model saved

# %%
plt.figure(2, figsize=[10,5])
plt.plot(score_list,'b.',ms=1.5)
plt.xlabel('Episode')
plt.ylabel('Score')
plt.title(f'300k, Discount = 0.9, exploration_decay_rate=4, K=1, Learning rate=(0.9 0.015), \n linear space interval = 40,last 1000 Training average scores = {np.average((score_list[-1000:]))}')
plt.savefig('300k, Discount = 0.9, exploration_decay_rate=4, K=1, Learning rate=(0.9 0.015), linear space interval = 40.png')
plt.show()

# %%
with open('MountainCar-v0-q-learning.pickle', 'rb') as f:
    Q = pickle.load(f)
    print("Model loaded!")

scores = []
env = gym.make('MountainCar-v0')


for _ in range(100):
    score = 0
    state = env.reset()
    while True:
        state = linear_state(state)
        action = np.argmax(Q[state]) if state in Q else np.random.choice([0, 1, 2])
        state, reward, done, _ = env.step(action)
        score += reward
        if done:
            scores.append(score)
            break
env.close()
print(f'Average score: {sum(scores)/len(scores)}')
plt.figure(2, figsize=[10,5])
plt.plot(scores, 'b.')
plt.xlabel('Episode')
plt.ylabel('Score')
plt.title(f'300k, Discount = 0.9, exploration_decay_rate=4, K=1, Learning rate=(0.9 0.015), \n \
      linear space interval = 40, 100 Test Scores:{sum(scores)/len(scores)}')
plt.savefig('300k, 0.9, e=4, K=1, Lr=(0.9 0.015),interval = 40.png')
plt.show()
# Out:
# Model loaded!
# Average score: -117.68

# %%
import gym
import numpy as np
import pickle
from collections import defaultdict
import matplotlib.pyplot as plt
import time

# %%
# Out:
# episode: 0 ; last 5000 score: -200.0 last 1000 score: -200.0 ; last 1000 max: -200.0
# episode: 10000 ; last 5000 score: -200.0 last 1000 score: -200.0 ; last 1000 max: -200.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-352fb5a49afe> in <module>()
#      34             action = np.random.choice([0, 1, 2])
#      35
# ---> 36         next_s, reward, done, _ = env.step(action)
#      37         if next_s[0] > 0.4:
#      38             reward += 1
#
# /usr/local/lib/python3.6/dist-packages/gym/wrappers/time_limit.py in step(self, action)
#      14     def step(self, action):
#      15         assert self._elapsed_steps is not None, "Cannot call env.step() before calling reset()"
# ---> 16         observation, reward, done, info = self.env.step(action)
#      17         self._elapsed_steps += 1
#      18         if self._elapsed_steps >= self._max_episode_steps:
#
# /usr/local/lib/python3.6/dist-packages/gym/envs/classic_control/mountain_car.py in step(self, action)
#      47         position, velocity = self.state
#      48         velocity += (action-1)*self.force + math.cos(3*position)*(-self.gravity)
# ---> 49         velocity = np.clip(velocity, -self.max_speed, self.max_speed)
#      50         position += velocity
#      51         position = np.clip(position, self.min_position, self.max_position)
#
# <__array_function__ internals> in clip(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py in clip(a, a_min, a_max, out, **kwargs)
#    2082
#    2083     """
# -> 2084     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#    2085
#    2086
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      59
#      60     try:
# ---> 61         return bound(*args, **kwds)
#      62     except TypeError:
#      63         # A TypeError occurs if the object does have such a method in its
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py in _clip(a, min, max, out, casting, **kwargs)
#     107             min = -float('inf')
#     108             using_deprecated_nan = True
# --> 109         if _clip_dep_is_scalar_nan(max):
#     110             max = float('inf')
#     111             using_deprecated_nan = True
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py in _clip_dep_is_scalar_nan(a)
#      64     # guarded to protect circular imports
#      65     from numpy.core.fromnumeric import ndim
# ---> 66     if ndim(a) != 0:
#      67         return False
#      68     try:
#
# <__array_function__ internals> in ndim(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py in _ndim_dispatcher(a)
#    3031
#    3032
# -> 3033 def _ndim_dispatcher(a):
#    3034     return (a,)
#    3035
#
# KeyboardInterrupt:

# %%
plt.figure(2, figsize=[10,5])
plt.plot(score_list,'b.',ms=1.5)
plt.xlabel('Episode')
plt.ylabel('Score')
plt.title(f'400k Training')
plt.savefig('400k Training Scores.png')
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
print( os.getcwd() )
print( os.listdir() )
# Out:
# /content
# ['.config', '200k Training Scores.png', 'MountainCar-v0-q-learning.pickle', 'drive', 'sample_data']

# %%
from google.colab import files
files.download( "200k Training Scores.png" )
